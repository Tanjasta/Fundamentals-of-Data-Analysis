# %% [markdown]
# # Fundamentals of Data Analysis Project
#
# **Tatjana Staunton**
#
# ***

# %% [markdown]
# #### Task
#
# >• The project is to create a notebook investigating the variables and
# data points within the well-known iris flower data set associated
# with Ronald A Fisher.
#
# >• In the notebook, you should discuss the classification of each
# variable within the data set according to common variable types
# and scales of measurement in mathematics, statistics, and Python.
#
# >• Select, demonstrate, and explain the most appropriate summary
# statistics to describe each variable.
#
# >• Select, demonstrate, and explain the most appropriate plot(s) for
# each variable.
#
# >• The notebook should follow a cohesive narrative about the data
# set.

# %% [markdown]
# ![Iris Dataset](data:image/jpeg;base64,...)

# %% [markdown]
# #### Overview of Fisher's Iris Dataset
#
# The Iris dataset is a popular dataset in the field of machine learning and statistics. It was introduced by the British biologist and statistician Sir Ronald A. Fisher in 1936.  The dataset is based on a study where measurements were taken from three species of iris flowers: setosa, versicolor, and virginica. There are four features (attributes) measured for each flower:
# * Sepal length (in cm)
# * Sepal width (in cm)
# * Petal length (in cm)
# * Petal width (in cm)
# There are three classes:
# * Iris setosa
# * Iris versicolor
# * Iris virginica
#
# There are typically 150 instances in the dataset, with 50 instances for each of the three species. The Iris dataset has become a classic example in the field and is frequently used in tutorials and educational materials for introducing concepts of machine learning and data analysis.

# %% [markdown]
# #### Variables
#
# **Species**
# *Type: Categorical Variable.
#
# * Scale of Measurement: Nominal Scale.
#
# The dataset includes three species: Iris setosa, Iris versicolor, and Iris virginica.
#
# The dataset is balanced, with each species represented by an equal number of instances (50).
#
# * Relation to Other Variables: Each species exhibits unique patterns in its sepal and petal measurements. For instance, Iris setosa is characterised by smaller petals, a distinct feature for classification.
#
# **Sepal Length, Sepal Width, Petal Length, Petal Width**
#
# * Type: Continuous Variable.
# * Scale of Measurement: Ratio Scale.
#
# Sepal Length,Sepal Width, Petal Length, Petal Width are numerical measurement which measured in units.
# Correlations between petal length and width, as well as sepal dimensions, are evident and can be used to distinguish between species.
#
# **Summary**
#
# * Continuous Variables: Sepal Length, Sepal Width, Petal Length, Petal Width. These are all ratio scale measurements because they are quantitative measurements with meaningful zero points.
#
# * Categorical Variable: Species. This is a nominal scale measurement as it categorises data without any order or ranking.

# %% [markdown]
# #### Analysis of Fisher's Iris Dataset

# %%
# Importing libraries.
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Geting data from CSV.
df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Counting the frequency of each species in the dataset.
species_counts = df['species'].value_counts()

print("Frequency Counts for Species:\n", species_counts)
# Out:
# Frequency Counts for Species:
#  setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.mean()
# Out:
# /var/folders/2h/g_24clt56v74sc_q901d05f00000gn/T/ipykernel_5081/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
df.max()
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %%
df.min()
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df[['sepal_length', 'species']]
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %%
df[['sepal_width', 'species']]
# Out:
#      sepal_width    species
# 0            3.5     setosa
# 1            3.0     setosa
# 2            3.2     setosa
# 3            3.1     setosa
# 4            3.6     setosa
# ..           ...        ...
# 145          3.0  virginica
# 146          2.5  virginica
# 147          3.0  virginica
# 148          3.4  virginica
# 149          3.0  virginica
#
# [150 rows x 2 columns]

# %%
df[['petal_length', 'species']]
# Out:
#      petal_length    species
# 0             1.4     setosa
# 1             1.4     setosa
# 2             1.3     setosa
# 3             1.5     setosa
# 4             1.4     setosa
# ..            ...        ...
# 145           5.2  virginica
# 146           5.0  virginica
# 147           5.2  virginica
# 148           5.4  virginica
# 149           5.1  virginica
#
# [150 rows x 2 columns]

# %%
df[['petal_width', 'species']]
# Out:
#      petal_width    species
# 0            0.2     setosa
# 1            0.2     setosa
# 2            0.2     setosa
# 3            0.2     setosa
# 4            0.2     setosa
# ..           ...        ...
# 145          2.3  virginica
# 146          1.9  virginica
# 147          2.0  virginica
# 148          2.3  virginica
# 149          1.8  virginica
#
# [150 rows x 2 columns]

# %%
df.loc[df.loc[:,'species'] == 'setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
# Creating plots setosa.
sns.pairplot(df.loc[df.loc[:,'species'] == 'setosa'])

# %%
# Adding color to the plots.
sns.pairplot(df.loc[df.loc[:,'species'] == 'setosa'], hue='sepal_length')

# %%
df.loc[df.loc[:,'species'] == 'versicolor']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
# Creating plots for versicolor.
sns.pairplot(df.loc[df.loc[:,'species'] == 'versicolor'])

# %%
# Adding color to the plots.
sns.pairplot(df.loc[df.loc[:,'species'] == 'versicolor'], hue='sepal_length')

# %%
df.loc[df.loc[:,'species'] == 'virginica']
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
# Creating plots for virginica.
sns.pairplot(df.loc[df.loc[:,'species'] == 'virginica'])

# %%
# Adding color to the plots.
sns.pairplot(df.loc[df.loc[:,'species'] == 'virginica'], hue='sepal_length')

# %%
# Creating plots.
sns.pairplot(df)

# %%
# Adding color to the plots.
sns.pairplot(df, hue='species')

# %% [markdown]
# #### Conclusion
#
# The analysis of the Iris dataset has yielded valuable insights into the physical characteristics of Iris flowers. Through careful examination of both the continuous variables (sepal length, sepal width, petal length, and petal width) and the categorical variable (species), significant patterns and relationships distinguishing the three species - Iris setosa, Iris versicolor, and Iris virginica - were uncovered.
#
# The findings from the analysis include distinct size variations in petals and sepals among the species, with notable differences in average measurements. A notable correlation was observed between petal length and width. Additionally, the balanced representation of each species in the dataset provides a solid foundation for analysis.
#
# The Fisher Iris dataset serves as an exemplary model for classification tasks, demonstrating how quantitative measurements can effectively categorise and differentiate between closely related species.

# %% [markdown]
# #### References
#
# http://www.lac.inpe.br/~rafael.santos/Docs/CAP394/WholeStory-Iris.html
#
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png
#
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv
#
# http://archive.ics.uci.edu/ml/datasets/Iris
#
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# https://www.simplilearn.com/what-is-nominal-data-article
#
# https://pandas.pydata.org/docs/user_guide/index.html
#
# https://vlegalwaymayo.atu.ie/course/view.php?id=8771
#
# https://seaborn.pydata.org/

# %% [markdown]
# # End
#
# ***
